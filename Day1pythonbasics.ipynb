# %%
print('hello world')
# Out:
# hello world

# %%
print('new')
# Out:
# new

# %% [markdown]
# here you can write notes by clicking on markdown from the dropbox next to run, it is no longer a python cell

# %%
 3/2
# Out:
# 1.5

# %% [markdown]
# mod operator

# %%
7%4
# Out:
# 3

# %%
50%5
# Out:
# 0

# %%
5**2
# Out:
# 25

# %%
2+10*10+3
# Out:
# 105

# %%
(2+10)*(10+3)
# Out:
# 156

# %%
a=5

# %%
a+a
# Out:
# 10

# %%
a=a+a

# %%
a
# Out:
# 10

# %%
print('hello \nworld')
# Out:
# hello
# world

# %%
len('I am')
# Out:
# 4
