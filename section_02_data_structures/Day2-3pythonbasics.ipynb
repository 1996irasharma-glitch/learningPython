# %%
mystring='sanvi'

# %%
mystring[2:]
# Out:
# 'nvi'

# %%
mystring[:5]
# Out:
# 'sanvi'

# %%
mystring[::2]
# Out:
# 'sni'

# %%
mystring[2:4:2]
# Out:
# 'n'

# %%
#string concatenation

# %%
name='sam'

# %%
'my name is '+ name
# Out:
# 'my name is sam'

# %%
x= 'my name is '+ name

# %%
x= x + 'my name is '+ name

# %%
x
# Out:
# 'my name is sammy name is sammy name is sammy name is sam'

# %%
#multiplication of letter
letter='z'

# %%
letter*10
# Out:
# 'zzzzzzzzzz'

# %%
2+3
# Out:
# 5

# %%
'2'+'3'
# Out:
# '23'

# %%
#be careful of the above problem

# %%
i= 'ira'

# %%
i.upper
# Out:
# <function str.upper()>

# %%
i.upper()
# Out:
# 'IRA'

# %%
#brackets are important dont forget them

# %%
i.split()
# Out:
# ['ira']

# %%
i='ira sharma'

# %%
i.split()
# Out:
# ['ira', 'sharma']

# %%
i.split(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 i.split(r)
#
# NameError: name 'r' is not defined

# %%
i.split('r')
# Out:
# ['i', 'a sha', 'ma']

# %%
#string interplolation
#two methods i).format() and ii)f-strings

# %%
print('This is a string {}'.format('Inserted'))
# Out:
# This is a string Inserted

# %%
print('The {} {} {}' .format('fox','brown','quick') )
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0}' .format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print('The {q} {f} {b}'.format(f='fox', b='brown', q='quick'))
# Out:
# The quick fox brown

# %%
result=100/777
print("The result was {}".format(result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r:1.3f}".format(r=result))
#1 in the curly bracket is just the width value, usually it ends up adding white space
# Out:
# The result was 0.129

# %%
#f-string
name= 'ira'
print(f'Hello, her name is {name}')
# Out:
# Hello, her name is ira

# %%
name='ira'
age=3
print(f'{name} is {age} years old')
# Out:
# ira is 3 years old
